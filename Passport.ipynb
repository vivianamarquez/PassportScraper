# %%
import re
import time
import random
import pandas as pd

from urlextract import URLExtract
import tldextract

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %%
link = 'https://iafdb.travel.state.gov/DefaultForm.aspx'

# %% [markdown]
# #### Initiate

# %%
driver = webdriver.Firefox(executable_path='/Users/vrai/Downloads/geckodriver')
driver.get(link)

# %%
driver.close()

# %% [markdown]
# #### Fill out initial form

# %%
search_by = driver.find_element_by_id("rdoZipCode")
search_by.click()
driver.implicitly_wait(10)

# %%
zip_code = driver.find_element_by_id("txtZipCode")
zip_code.send_keys('33132')
driver.implicitly_wait(10)

# %%
closest = driver.find_element_by_id("rdoNumClosest")
closest.click()
driver.implicitly_wait(10)

# %%
Select(driver.find_element_by_id("ddnNumClosest")).select_by_value('250')
driver.implicitly_wait(10)

# %%
send = driver.find_element_by_id("btnSearch")
send.click()
driver.implicitly_wait(10)

# %% [markdown]
# #### Get JS link for all facilities

# %%
all_facilities = []
distances = []

# %%
for i in range(0,13):
    table_id = driver.find_element(By.ID, 'dgFacilityList')
    facilities = [f.get_attribute('href') for f in table_id.find_elements_by_tag_name("a") if "PostBack" not in f.get_attribute('href')]
    all_facilities.extend(facilities)
    
    for row in table_id.find_elements(By.TAG_NAME, 'tr'):
        val = row.find_elements(By.TAG_NAME, 'td')[-1].text.strip()
        if val.isdigit():
            distances.append(val)
    
    driver.execute_script("javascript:__doPostBack('dgFacilityList$ctl24$ctl01','')") # Next Page
    time.sleep(10)

# %%
print(len(all_facilities))
len(set(all_facilities)) == len(all_facilities)
# Out:
# 250
# True

# %%
print(len(distances))
len(set(distances)) == len(distances)
# Out:
# 250
# False

# %% [markdown]
# #### Get info for all facilities

# %%
facilities_info = []

# %%
for f in all_facilities:
    facility = []
    
    driver.execute_script(f)
    
    facility.append(driver.find_element_by_id("tcFacilityName").text)
    facility.append(driver.find_element_by_id("tcFacilityType").text)
    facility.append(driver.find_element_by_id("tcFacilityAddress").text)
    facility.append(driver.find_element_by_id("tcPublicPhone").text)

    facility.append(driver.find_element_by_id("tblConveniences").find_elements(By.TAG_NAME, "td")[3].text)
    facility.append(driver.find_element_by_id("tblHours").find_elements(By.TAG_NAME, "td")[-1].text)
    
    facilities_info.append(facility)
    
    back = driver.find_element_by_id("hlResultsBottom")
    back.click()
    driver.implicitly_wait(10)

# %%
driver.close()

# %% [markdown]
# ### Create a data frame

# %%
df = pd.DataFrame(facilities_info)
df.columns = ['Name', 'Type', 'Address', 'Phone', 'PhotoOnSite', 'Comments']
df['Distance'] = distances
df.sample(5)
# Out:
#                                                   Name       Type  \
# 238                     BRANTLEY COUNTY SUPERIOR COURT      Court
# 125        OSCEOLA COUNTY CLERK OF COURT - MAIN OFFICE      Court
# 28                                     CITY OF MIRAMAR  Municipal
# 73   COLLIER COUNTY CLERK OF COURT - GOLDEN GATE ANNEX      Court
# 72   COLLIER COUNTY CLERK OF CIRCUIT COURT - MAIN O...      Court
#
#                                     Address       Phone PhotoOnSite  \
# 238   234 BRANTLEY STREET NAHUNTA, GA 31553  9124625635          No
# 125     2 COURTHOUSE SQ KISSIMMEE, FL 34741  4077423530          No
# 28   2300 CIVIC CENTER PL MIRAMAR, FL 33025  9546023011         Yes
# 73   4715 GOLDEN GATE PKWY NAPLES, FL 34116  2392522750          No
# 72    3315 E TAMIAMI TRL E NAPLES, FL 34112  2392527242          No
#
#                                               Comments Distance
# 238  Appointments are required please call (912)462...      387
# 125  By Appointment Only - Please call 407-742-3530...      190
# 28   ***BY APPOINTMENT ONLY*** To schedule an appoi...       15
# 73                  Appointment Not Required | Walk-In       98
# 72   Appointments please call (239)252-7242 for fur...       98

# %% [markdown]
# #### ETL & EDA

# %%
df.Type.value_counts()
# Out:
# Postal            127
# Court              87
# Municipal          17
# Library            11
# School              5
# County / State      3
# Name: Type, dtype: int64

# %%
df.PhotoOnSite.value_counts()
# Out:
# Yes    189
# No      61
# Name: PhotoOnSite, dtype: int64

# %%
def url_normalizer(url):
    if url is None:
        return url
    
    url = url.lower()
    
    if "usps.com" in url:
        return "https://usps.com/scheduler"
    
    url = url.replace("http://", "https://")
    url = url.replace("www.","")
    url = url.strip(".")
    url = url.strip("/")
    
    if not url.startswith("https://"):
        url = f"https://{url}"
    
    return url
        

df['url'] = df.Comments.apply(lambda val: extractor.find_urls(val))
df['url'] = df.url.apply(lambda val: None if len(val)==0 else val[0])
df['url'] = df.url.apply(lambda val: url_normalizer(val))

df['domain'] = df.url.apply(lambda link: None if link is None else tldextract.extract(link).domain)

# %%
df.domain.value_counts().head(12)
# Out:
# usps                 121
# myorangeclerk          4
# mypalmbeachclerk       3
# lakecountyclerk        3
# mypinellasclerk        2
# browardclerk           2
# stlucieclerk           2
# hernandoclerk          2
# clayclerk              2
# citrusclerk            2
# duvalclerk             2
# martincountyclerk      1
# Name: domain, dtype: int64

# %%
def normalize_phone(phone):
    if phone is None:
        return None
    
    phone = re.sub("[^0-9]", "", phone)
    phone = f"{phone[:3]}-{phone[3:-4]}-{phone[-4:]}"
    return phone

df['phone'] = df.Comments.apply(lambda val: re.findall(r"\(?\b[2-9][0-9]{2}\)?[-. ]?[2-9][0-9]{2}[-. ]?[0-9]{4}\b",val))
df['phone'] = df.phone.apply(lambda val: None if len(val)==0 else val[0])
df['phone'] = df.phone.apply(lambda val: normalize_phone(val))

# %%
df.phone.value_counts()
# Out:
# 855-864-3379    4
# 863-534-4000    3
# 941-861-7436    2
# 352-540-6768    2
# 941-741-4022    1
#                ..
# 954-831-2311    1
# 912-427-5930    1
# 386-345-3574    1
# 561-624-6650    1
# 305-295-5000    1
# Name: phone, Length: 69, dtype: int64

# %%
def comment_normalizer(comment):
    comment = comment.lower()
    
    urls = extractor.find_urls(comment)
    for url in urls:
        comment = comment.replace(url, " ")
    
    phones = re.findall(r"\(?\b[2-9][0-9]{2}\)?[-. ]?[2-9][0-9]{2}[-. ]?[0-9]{4}\b",comment)
    for phone in phones:
        comment = comment.replace(phone, " ")
        
    comment = re.sub("[^a-zA-Z\s]+", " ", comment)
    comment = comment.strip()
    
    comment = " ".join(comment.split())
    
    return comment

# %%
def needs_appointment(comment):
    comment = comment_normalizer(comment)
    
    no = ['not required', 'walk in', 'no appointment']
    yes = ['appointment only', 'appointment required', 
           'appointments only', 'appointments required']
    
    for n in no:
        if n in comment:
            return False
        
    for y in yes:
        if y in comment:
            return True
        
    return "Unknown"

# %%
df['NeedsAppointment'] = df.Comments.apply(lambda val: needs_appointment(val))

# %%
df.NeedsAppointment.value_counts()
# Out:
# True       160
# False       48
# Unknown     42
# Name: NeedsAppointment, dtype: int64

# %% [markdown]
# ## Best candidates

# %% [markdown]
# #### Let's examine USPS first

# %%
df_usps = df[df.domain=='usps']
df_other = df[df.domain!='usps']

# %%
df_usps['zip'] = df_usps.Address.apply(lambda val: val.split()[-1])
# Out:
# <ipython-input-212-623e4cdb498f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usps['zip'] = df_usps.Address.apply(lambda val: val.split()[-1])

# %%
df_usps.to_csv("passport_usps.csv", index=False)

# %%
df_usps.tail(50)
# Out:
#                                           Name    Type  \
# 139                     USPS FALKENBURG BRANCH  Postal
# 140                      USPS SAND LAKE BRANCH  Postal
# 141                 USPS DIXIE VILLAGE STATION  Postal
# 142                       KATHLEEN POST OFFICE  Postal
# 144              USPS DOWNTOWN ORLANDO STATION  Postal
# 145                          USPS ORLANDO MOWU  Postal
# 148                   USPS HERNDON POST OFFICE  Postal
# 149                     USPS GULFWINDS STATION  Postal
# 153                      USPS MIMS POST OFFICE  Postal
# 154                       USPS GATEWAY STATION  Postal
# 155                            USPS TAMPA MOWU  Postal
# 158                 USPS NEW TAMPA POST OFFICE  Postal
# 159               USPS ZEPHYRHILLS POST OFFICE  Postal
# 160          USPS CASSELBERRY MAIN POST OFFICE  Postal
# 161               USPS ORLANDO LOCKHART BRANCH  Postal
# 162            USPS WINTER SPRINGS POST OFFICE  Postal
# 163                        USPS EHRLICH BRANCH  Postal
# 165                  USPS OAK HILL POST OFFICE  Postal
# 166                  USPS SEMINOLE POST OFFICE  Postal
# 169         USPS LAND O LAKES MAIN POST OFFICE  Postal
# 171           USPS CLEARWATER MAIN POST OFFICE  Postal
# 172        USPS INDIAN ROCKS BEACH POST OFFICE  Postal
# 174                   USPS OLDSMAR POST OFFICE  Postal
# 176                    USPS DEBARY POST OFFICE  Postal
# 180      USPS NEW PORT RICHEY MAIN POST OFFICE  Postal
# 181            US POSTAL SERVICE LAKE HELEN FL  Postal
# 186               BROOKSVILLE MAIN POST OFFICE  Postal
# 188                    USPS HUDSON POST OFFICE  Postal
# 191        USPS DAYTONA BEACH MAIN POST OFFICE  Postal
# 193           USPS DE LEON SPRINGS POST OFFICE  Postal
# 195               USPS SUMMERFIELD POST OFFICE  Postal
# 197                    USPS HOLDER POST OFFICE  Postal
# 200              USPS BUNNELL MAIN POST OFFICE  Postal
# 188                 13610 BIG BEND DR HUDSON, FL 34667  7278190073
# 191  500 BILL FRANCE BOULEVARD DAYTONA BEACH, FL 32114  3862746329
# 193   155 PONCE DE LEON BLVD DE LEON SPRINGS, FL 32130  3869854326
# 195           14560 S US HWY 301 SUMMERFIELD, FL 34491  3522452784
# 197                6906 N FLORIDA AVE HOLDER, FL 34445  3524895351
# 200                 704 E MOODY BVLD BUNNELL, FL 32110  3864378453
# 201              4545 S.W. 60TH AVENUE OCALA, FL 34474  3524217176
# 205                100 MATHE AVE INTERLACHEN, FL 32148  3866842228
# 208            13553 SW STATE ROAD 45 ARCHER, FL 32618  3524952565
# 210               1401 N MAIN ST GAINESVILLE, FL 32601  3522716392
# 215        1880 EASTWEST PKWY FLEMING ISLAND, FL 32003  9042648913
# 216      130 CORRIDOR ROAD PONTE VEDRA BEACH, FL 32082  9046863955
# 217             4411 SUNBEAM RD JACKSONVILLE, FL 32257  9043664852
# 219            10700 BEACH BLVD JACKSONVILLE, FL 32246  9046412172
# 223             1100 KINGS ROAD JACKSONVILLE, FL 32203  9043664888
# 225   7345 W MOUNT VERNON ST GLEN SAINT MARY, FL 32040  9042596789
# 227                       157 E MAIN ST MAYO, FL 32066  3862941623
# 229          1997 SADLER RD FERNANDINA BEACH, FL 32034  9044914680
# 232       724 CHARLIE SMITH SR HWY ST. MARYS, GA 31558  9127293301
# 235          805 GLOUCESTER STREET BRUNSWICK, GA 31520  9122801250
# 237                 687 LAKES BLVD LAKE PARK, GA 31636  2295597843
# 243         3698 INNER PERIMETER RD VALDOSTA, GA 31602  2292417209
# 246              2800 S ADAMS ST TALLAHASSEE, FL 32301  8502164286
#
#     PhotoOnSite  \
# 139         Yes
# 140         Yes
# 141         Yes
# 142         Yes
# 144         Yes
# 145         Yes
# 148         Yes
# 149         Yes
# 153         Yes
# 154         Yes
# 155         Yes
# 158         Yes
# 159         Yes
# 160         Yes
# 161         Yes
# 162         Yes
# 163         Yes
# 165         Yes
# 166         Yes
# 169         Yes
# 171         Yes
# 172         Yes
# 174         Yes
# 176         Yes
# 180         Yes
# 181         Yes
# 186         Yes
# 188         Yes
# 191         Yes
# 193         Yes
# 195         Yes
# 197         Yes
# 200         Yes
# 201         Yes
# 205         Yes
# 208         Yes
# 210         Yes
# 215         Yes
# 216          No
# 217         Yes
# 219         Yes
# 223         Yes
# 225         Yes
# 227         Yes
# 229         Yes
# 232         Yes
# 235         Yes
# 237         Yes
# 243         Yes
# 246         Yes
#
#                                                                                                             Comments  \
# 139                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 140                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 141                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 142                       ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler
# 144                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 145                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 148                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 149    ***BY APPOINTMENT ONLY*** To schedule an appointment call 727-327-8469, visit: http://www.usps.com/scheduler.
# 153                                                 Appointments - Website: usps.com/scheduler http://tools.usps.com
# 154                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 155                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 158  ***BY APPOINTMENT ONLY*** Including Saturdays To schedule an appointment, visit: http://tools.usps.com/rcas.htm
# 159                       ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/passports
# 160                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 161                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 162     ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/international/passports.htm
# 163                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 165                                             For appointments please call 386-345-3574 or visit website: usps.com
# 166                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 169                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 171                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 172                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 174                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 176                                     To schedule an appointment for passport services Website: usps.com/scheduler
# 180                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 181                                                                         For appointments visit website: usps.com
# 186     ***BY APPOINTMENT ONLY*** Call 800-275-8777 To schedule an appointment, visit: http://www.usps.com/scheduler
# 188                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 191                                                         For appointments please visit website usps.com/scheduler
# 193                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 195                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 197                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 200                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 201                       ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler
# 205                          To schedule an appointment, visit USPS.com Website and click on Schedule An Appointment
# 208                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 210                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 215                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 216                           BY APPOINTMENT ONLY - To schedule an appointment, Visit: http://www.usps.com/scheduler
# 217                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 219                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 223                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit https://www.usps.com/scheduler.
# 225                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 227             Appointment Not Required | Walk-In To schedule appointment: 386-294-1623 website: usps.com/scheduler
# 229                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
# 232                                                                 APPOINTMENTS ONLY: VISIT WWW.USPS.COM/SCHEDULER.
# 235                                                          TO SCHEDULE AN APPOINTMENT VISIT WWW.USPS.COM/SCHEDULER
# 237                                                 To schedule an appointment visit https://tools.usps.com/rcas.htm
# 243                                                                                    VISIT WWW. USPS.COM/SCHEDULER
# 246                      ***BY APPOINTMENT ONLY*** To schedule an appointment, visit: http://www.usps.com/scheduler.
#
#     Distance                         url domain         phone  \
# 139      199  https://usps.com/scheduler   usps          None
# 140      200  https://usps.com/scheduler   usps          None
# 141      201  https://usps.com/scheduler   usps          None
# 142      203  https://usps.com/scheduler   usps          None
# 144      203  https://usps.com/scheduler   usps          None
# 145      203  https://usps.com/scheduler   usps          None
# 148      204  https://usps.com/scheduler   usps          None
# 149      205  https://usps.com/scheduler   usps  727-327-8469
# 153      207  https://usps.com/scheduler   usps          None
# 154      207  https://usps.com/scheduler   usps          None
# 155      208  https://usps.com/scheduler   usps          None
# 158      209  https://usps.com/scheduler   usps          None
# 159      209  https://usps.com/scheduler   usps          None
# 160      210  https://usps.com/scheduler   usps          None
# 161      210  https://usps.com/scheduler   usps          None
# 162      211  https://usps.com/scheduler   usps          None
# 163      212  https://usps.com/scheduler   usps          None
# 165      213  https://usps.com/scheduler   usps  386-345-3574
# 166      214  https://usps.com/scheduler   usps          None
# 169      217  https://usps.com/scheduler   usps          None
# 171      218  https://usps.com/scheduler   usps          None
# 172      218  https://usps.com/scheduler   usps          None
# 174      219  https://usps.com/scheduler   usps          None
# 176      224  https://usps.com/scheduler   usps          None
# 180      229  https://usps.com/scheduler   usps          None
# 181      230  https://usps.com/scheduler   usps          None
# 186      235  https://usps.com/scheduler   usps  800-275-8777
# 188      235  https://usps.com/scheduler   usps          None
# 191      241  https://usps.com/scheduler   usps          None
# 193      244  https://usps.com/scheduler   usps          None
# 195      249  https://usps.com/scheduler   usps          None
# 197      257  https://usps.com/scheduler   usps          None
# 200      261  https://usps.com/scheduler   usps          None
# 201      262  https://usps.com/scheduler   usps          None
# 205      284  https://usps.com/scheduler   usps          None
# 208      296  https://usps.com/scheduler   usps          None
# 210      296  https://usps.com/scheduler   usps          None
# 215      312  https://usps.com/scheduler   usps          None
# 216      312  https://usps.com/scheduler   usps          None
# 217      316  https://usps.com/scheduler   usps          None
# 219      321  https://usps.com/scheduler   usps          None
# 223      327  https://usps.com/scheduler   usps          None
# 225      332  https://usps.com/scheduler   usps          None
# 227      341  https://usps.com/scheduler   usps  386-294-1623
# 229      342  https://usps.com/scheduler   usps          None
# 232      355  https://usps.com/scheduler   usps          None
# 235      380  https://usps.com/scheduler   usps          None
# 237      384  https://usps.com/scheduler   usps          None
# 243      400  https://usps.com/scheduler   usps          None
# 246      405  https://usps.com/scheduler   usps          None
#
#     NeedsAppointment    zip
# 139             True  33619
# 140             True  32819
# 141             True  32806
# 142             True  33849
# 144             True  32801
# 145             True  32862
# 148             True  32814
# 149             True  33711
# 153          Unknown  32754
# 154             True  33702
# 155             True  33630
# 158             True  33647
# 159             True  33542
# 160             True  32707
# 161             True  32810
# 162             True  32708
# 163             True  33618
# 165          Unknown  32759
# 166             True  33772
# 169             True  34639
# 171             True  33765
# 172             True  33785
# 174             True  34677
# 176          Unknown  32713
# 180             True  34653
# 181          Unknown  32744
# 186             True  34601
# 188             True  34667
# 191          Unknown  32114
# 193             True  32130
# 195             True  34491
# 197             True  34445
# 200             True  32110
# 201             True  34474
# 205          Unknown  32148
# 208             True  32618
# 210             True  32601
# 215             True  32003
# 216             True  32082
# 217             True  32257
# 219             True  32246
# 223             True  32203
# 225             True  32040
# 227            False  32066
# 229             True  32034
# 232             True  31558
# 235          Unknown  31520
# 237          Unknown  31636
# 243          Unknown  31602
# 246             True  32301

# %%
df_other.head(50)
# Out:
#                                                                         Name  \
# 1                                       CITY OF MIAMI BEACH - FINANCE OFFICE
# 5                                                              CITY OF MIAMI
# 6                                                       CITY OF CORAL GABLES
# 9                                                    VILLAGE OF KEY BISCAYNE
# 11                           NORTH BAY VILLAGE - OFFICE OF THE VILLAGE CLERK
# 13                                                 USPS SURFSIDE POST OFFICE
# 14                                                       CITY OF NORTH MIAMI
# 15                                                        CITY OF WEST MIAMI
# 19                                          NORTH MIAMI BEACH PUBLIC LIBRARY
# 21                                                        CITY OF SWEETWATER
# 23                                               NORTH DADE REGIONAL LIBRARY
# 28                                                           CITY OF MIRAMAR
# 29                                                   VILLAGE OF PALMETTO BAY
# 30                                                    CITY OF PEMBROKE PINES
# 31                 BROWARD COUNTY CLERK OF COURT - SOUTH REGIONAL COURTHOUSE
# 34            MIAMI-DADE PUBLIC LIBRARY SYSTEM - SOUTH DADE REGIONAL LIBRARY
# 36                                                       CITY OF COOPER CITY
# 37                        BROWARD COUNTY CLERK OF COURT - CENTRAL COURTHOUSE
# 38    BROWARD COUNTY RECORDS, TAXES AND TREASURY DIVISION - PASSPORT SECTION
# 39                  BROWARD COUNTY CLERK OF COURT - WEST REGIONAL COURTHOUSE
# 45                             CITY OF CORAL SPRINGS - CITY HALL IN THE MALL
# 6   3054605351         Yes
# 9   3053658900          No
# 11  3057567171          No
# 13  3058616054         Yes
# 14  3058959817          No
# 15  3052661122         Yes
# 19  3059482970          No
# 21  3052073343         Yes
# 23  3056256424          No
# 28  9546023011         Yes
# 29  3052591234         Yes
# 30  9544501043         Yes
# 31  9548310342         Yes
# 34  3052338140          No
# 36  9544344300          No
# 37  9548312343         Yes
# 38  9548314000          No
# 39  9548312311         Yes
# 45  9543441828         Yes
# 46  9548311456         Yes
# 49  5612741588          No
# 51  5616422024         Yes
# 53  5612332788          No
# 58  5619964843          No
# 60  5619965390         Yes
# 62  2396952511          No
# 63  5616246650          No
# 65  2392522909          No
# 66  2392522654          No
# 67  7725461308         Yes
# 68  8636755217         Yes
# 69  3057435238         Yes
# 71  7722885553         Yes
# 72  2392527242          No
# 73  2392522750          No
# 75  2392525477          No
# 76  8639466010          No
# 80  7728717200         Yes
# 83  7724623207         Yes
# 85  2395907925          No
# 87  2395335007          No
# 88  2395740411         Yes
# 89  8637632131          No
# 90  3052955000         Yes
# 91  3058093186          No
# 94  7722263100          No
# 96  9416372335          No
# 99  8639934876         Yes
#
#                                                                                                                        Comments  \
# 1                           **To schedule appointments please call 305-673-7420 https://cmbappt.miamibeachfl.gov/naoa/index.jsp
# 5                                                     By Appointments Only Schedule Appointment visit www.miamigov.com/passport
# 6                            By Appointments Only 305-460-5351 Please schedule an appointment via www.coralgables.com/passports
# 9                                                                     ***BY APPOINTMENT ONLY*For appointments call 305-365-8900
# 11                ***By Appointment Only***Contact 305-756-7171 for further assistance or visit: https://northbayvillage-fl.gov
# 13                    ***BY APPOINTMENT ONLY***To schedule an appointment, visit: http://www.usp.com/international/passport.htm
# 14                                     To schedule appointments please call(305) 895-9817 Website: https://www.northmiamifl.gov
# 15                                                                   By Appointments Only - For further assistance 305-266-1122
# 19                                   Appointment Only** Please call 305-948-2970 for further assistance Website: www.nmblib.com
# 21                                                                                Appointments Only: visit website: buk.app.com
# 23                                             Appointments Required - Please contact us at 305 625-6424 Website: www.dmpls.org
# 28                                                ***BY APPOINTMENT ONLY*** To schedule an appointment, visit www.miramarfl.gov
# 29                                          By Appointment Only - Please call (305)259-1234 or online at www.palmettobay-fl.gov
# 30     ***BY APPOINTMENT ONLY*** To schedule an appointment, visit www.ppines.com/153/Passport-Office or contact (954)450-1043.
# 31                                         By Appointment Only - Please call 954-831-0342 Website: htttp://www.browardclerk.org
# 34                                  BY APPOINTMENT ONLY To schedule an appointment contact (305)233-8140 Website: www.mdpls.org
# 36                                                      By Appointments Only Please contact us via https://www.coopercityfl.org
# 37                                                                                           Appointment Not Required | Walk-In
# 38                                                                                           Appointment Not Required | Walk-In
# 39                                            By Appointment Only Please call 954-831-2311 Website: http://www.browardclerk.org
# 45  APPOINTMENTS: TUES/THURS 3:00PM-5:00PM SATURDAY: 10:00AM-4:00PM TO MAKE AN APPOINTMENT VISIT: WWW.CORALSPRINGS.ORG/PASSPORT
# 46                                          By Appointment Only - Please call 954-831-1456 Website: http://www.browardclerk.org
# 49                         By Appointments Only https://www.mypalmbeachclerk.com/records/passports/request-passport-appointment
# 51                                                                                                Website: www.greenacresfl.gov
# 53                         By Appointment Only Please call (561)233-2788 for further assistance. http://www.pbclibrary/passport
# 58                                             Appointment Required via phone 561-996-4843 or website: www.mypalmbeachclerk.com
# 60                                                                              ***No Appointment Required*** Tel. 561 983-9105
# 62                                                                                           Appointment Not Required | Walk-In
# 63         Appointment Required - Please call 561-624-6650 or visit Website: https://www.mypalmbeachclerk.com/records/passports
# 65                                                                  Appointment Not Required | Walk-In Please call 239-252-2909
# 66                                                                                 No Appointments Required - Walk-ins Welcomed
# 67                                                 For appointments please call 772-546-1308 Website: www.martincountyclerk.com
# 68   By Appointments Only Please contact us at 863-675-5217 OR 863-675-5216 for further assistance. Website: wwwhendryclerk.org
# 69                                                        ***By Appointment Only***Contact 305-743-5238 for Further Assistance.
# 71                                                        For appointment please call 772-288-5553 Website: www.martinclerk.com
# 72                               Appointments please call (239)252-7242 for further assistance. Visit Website: collierclerk.com
# 73                                                                                           Appointment Not Required | Walk-In
# 75                                                                                           Appointment Not Required | Walk-In
# 76                                                                                           Appointment Not Required | Walk-In
# 80                                                                         By appointment only at Website: www.stlucieclerk.com
# 83                                                                             By appointment only at Website: stlucieclerk.com
# 85                                                                                        For appointments contact 239-590-7925
# 87                                                                       By Appointments Only Please contact us at 239-533-5007
# 88                                                         By Appointments Only Please call 239-574-0411 for further assistance
# 89                                                                                               ***No Appointments Required***
# 90                                                      By Appointments Only Please contact 305-295-5000 for further assistance
# 91       No appointments necessary - you may call (305) 809-3186 - Website: https://www.cfk.edu/community-resources/us-passport
# 94                                                             Appointment only - visit our Website: www.clerk.indian-river.org
# 96                                                                                           Appointment Not Required | Walk-In
# 99                                                                      By Appointment Only - Please contact us at 863-993-4876
#
#    Distance  \
# 1         3
# 5         5
# 6         6
# 9         6
# 11        6
# 13        7
# 14        7
# 15        7
# 19        9
# 21       10
# 23       11
# 28       15
# 29       15
# 30       15
# 31       16
# 34       17
# 36       20
# 37       23
# 38       23
# 39       23
# 45       32
# 46       36
# 49       46
# 51       56
# 53       61
# 58       67
# 60       70
# 62       73
# 63       74
# 65       76
# 66       85
# 67       86
# 68       91
# 69       92
# 71       96
# 72       98
# 73       98
# 75      102
# 76      103
# 80      107
# 83      115
# 85      116
# 87      119
# 88      123
# 89      123
# 90      125
# 91      125
# 94      128
# 96      138
# 99      142
#
#                                                                             url  \
# 1                               https://cmbappt.miamibeachfl.gov/naoa/index.jsp
# 5                                                 https://miamigov.com/passport
# 6                                             https://coralgables.com/passports
# 9                                                                          None
# 11                                               https://northbayvillage-fl.gov
# 13                                   https://usp.com/international/passport.htm
# 14                                                     https://northmiamifl.gov
# 15                                                                         None
# 19                                                           https://nmblib.com
# 21                                                          https://buk.app.com
# 23                                                            https://dmpls.org
# 28                                                        https://miramarfl.gov
# 29                                                   https://palmettobay-fl.gov
# 30                                       https://ppines.com/153/passport-office
# 31                                             https://htttp://browardclerk.org
# 34                                                            https://mdpls.org
# 36                                                     https://coopercityfl.org
# 37                                                                         None
# 38                                                                         None
# 39                                                     https://browardclerk.org
# 45                                            https://coralsprings.org/passport
# 46                                                     https://browardclerk.org
# 49  https://mypalmbeachclerk.com/records/passports/request-passport-appointment
# 51                                                     https://greenacresfl.gov
# 53                                                                         None
# 58                                                 https://mypalmbeachclerk.com
# 60                                                                         None
# 62                                                                         None
# 63                               https://mypalmbeachclerk.com/records/passports
# 65                                                                         None
# 66                                                                         None
# 67                                                https://martincountyclerk.com
# 68                                                   https://wwwhendryclerk.org
# 69                                                                         None
# 71                                                      https://martinclerk.com
# 72                                                     https://collierclerk.com
# 73                                                                         None
# 75                                                                         None
# 76                                                                         None
# 80                                                     https://stlucieclerk.com
# 83                                                     https://stlucieclerk.com
# 85                                                                         None
# 87                                                                         None
# 88                                                                         None
# 89                                                                         None
# 90                                                                         None
# 91                              https://cfk.edu/community-resources/us-passport
# 94                                               https://clerk.indian-river.org
# 96                                                                         None
# 99                                                                         None
#
#                 domain         phone NeedsAppointment
# 1         miamibeachfl  305-673-7420          Unknown
# 5             miamigov          None             True
# 6          coralgables  305-460-5351             True
# 9                 None  305-365-8900             True
# 11  northbayvillage-fl  305-756-7171             True
# 13                 usp          None             True
# 14        northmiamifl  305-895-9817          Unknown
# 15                None  305-266-1122             True
# 19              nmblib  305-948-2970             True
# 21                 app          None             True
# 23               dmpls  305-625-6424             True
# 28           miramarfl          None             True
# 29      palmettobay-fl  305-259-1234             True
# 30              ppines  954-450-1043             True
# 31               htttp  954-831-0342             True
# 34               mdpls  305-233-8140             True
# 36        coopercityfl          None             True
# 37                None          None            False
# 38                None          None            False
# 39        browardclerk  954-831-2311             True
# 45        coralsprings          None          Unknown
# 46        browardclerk  954-831-1456             True
# 49    mypalmbeachclerk          None             True
# 51        greenacresfl          None          Unknown
# 53                None  561-233-2788             True
# 58    mypalmbeachclerk  561-996-4843             True
# 60                None  561-983-9105            False
# 62                None          None            False
# 63    mypalmbeachclerk  561-624-6650             True
# 65                None  239-252-2909            False
# 66                None          None            False
# 67   martincountyclerk  772-546-1308          Unknown
# 68      wwwhendryclerk  863-675-5217             True
# 69                None  305-743-5238             True
# 71         martinclerk  772-288-5553          Unknown
# 72        collierclerk  239-252-7242          Unknown
# 73                None          None            False
# 75                None          None            False
# 76                None          None            False
# 80        stlucieclerk          None             True
# 83        stlucieclerk          None             True
# 85                None  239-590-7925          Unknown
# 87                None  239-533-5007             True
# 88                None  239-574-0411             True
# 89                None          None            False
# 90                None  305-295-5000             True
# 91                 cfk  305-809-3186            False
# 94        indian-river          None             True
# 96                None          None            False
# 99                None  863-993-4876             True

# %%
df_other.to_csv("passport_other.csv", index=False)
